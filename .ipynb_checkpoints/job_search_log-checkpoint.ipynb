# %%
import pandas as pd
# Out:
# /var/folders/wq/8mxmhthx1qjg6pq5jr3045k40000gn/T/ipykernel_53298/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('/Users/ryangeygan/Downloads/job_search.csv')

# %%
df
# Out:
#    Application Date                           Company  \
# 0          2/8/2024                           Pachama
# 1          2/9/2024                         Perennial
# 2          2/9/2024                          Resilinc
# 3         2/14/2024                      Burtch Works
# 4         2/14/2024               Zero Carbon Systems
# 5         2/15/2024  Lincoln Institute of Land Policy
# 6         2/16/2024                        Thalo Labs
# 7         2/23/2024                         HabiTerre
# 8         2/23/2024                          Boomitra
# 9         2/23/2024                               Ode
# 10        2/23/2024                    Vibrant Planet
# 11        2/27/2024                             Bunge
# 12        2/27/2024                           Amperon
# 13        2/27/2024                        Altruistiq
# 14        2/27/2024                            Afresh
# 15        2/27/2024                   Field to Market
# ...

# %%
new_apps = {
    'Application Date':['3/25/2024','3/25/2024','3/25/2024'],
    'Company': ['Arbor', 'Blumen', 'Streetlight'],
    'Role': ['Senior Data Scientist', 'Geospatial Engineer', 'Data Scientist'],
    'Phase': ['Application Submitted','Application Submitted','Application Submitted'],
    'Status': ['Pending','Pending','Pending'],
    'Domain': ['Energy', 'Energy', 'Transportation'],
    'Notes': [None, None, None], 
    'Date': [None, None, None], 
    '# Applications':[None, None, None]}

# %%
df2 = pd.concat([df, pd.DataFrame(new_apps)])

df2
# Out:
# /var/folders/wq/8mxmhthx1qjg6pq5jr3045k40000gn/T/ipykernel_53298/2757863759.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df2 = pd.concat([df, pd.DataFrame(new_apps)])
#    Application Date                           Company  \
# 0          2/8/2024                           Pachama
# 1          2/9/2024                         Perennial
# 2          2/9/2024                          Resilinc
# 3         2/14/2024                      Burtch Works
# 4         2/14/2024               Zero Carbon Systems
# 5         2/15/2024  Lincoln Institute of Land Policy
# 6         2/16/2024                        Thalo Labs
# 7         2/23/2024                         HabiTerre
# 8         2/23/2024                          Boomitra
# ...
